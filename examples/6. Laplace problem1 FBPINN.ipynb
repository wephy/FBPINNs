# %%
import numpy as np

from fbpinns.domains import RectangularDomainND
from fbpinns.problems import Laplace2D
from fbpinns.decompositions import RectangularDecompositionND
from fbpinns.networks import FCN
from fbpinns.schedulers import AllActiveSchedulerND
from fbpinns.constants import Constants, get_subdomain_ws
from fbpinns.trainers import FBPINNTrainer

XMIN, XMAX, YMIN, YMAX = 0, 3, 0, 3

subdomain_xs=[np.linspace(XMIN, XMAX, 10),
              np.linspace(YMIN, YMAX, 10)]

c = Constants(
    domain=RectangularDomainND,
    domain_init_kwargs = dict(
        xmin=np.array([0.,0.]),
        xmax=np.array([3.,3.])
        ),
    problem=Laplace2D,
    problem_init_kwargs = dict(n=5),
    decomposition=RectangularDecompositionND,
    decomposition_init_kwargs=dict(
        subdomain_xs=subdomain_xs,
        subdomain_ws=get_subdomain_ws(subdomain_xs, 3.4),
        unnorm=(0.,3.),
    ),
    network=FCN,
    network_init_kwargs = dict(
        layer_sizes = (2, 12, 12, 1),
    ),
    scheduler = AllActiveSchedulerND,
    ns=((100,100),),
    n_test=(100,100),
    n_steps=100000,
    clear_output=True,
)

run = FBPINNTrainer(c)
all_params = run.train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 42
#      16 c = Constants(
#      17     domain=RectangularDomainND,
#      18     domain_init_kwargs = dict(
#    (...)
#      38     clear_output=True,
#      39 )
#      41 run = FBPINNTrainer(c)
# ---> 42 all_params = run.train()
#
# File ~/FBPINNs/fbpinns/trainers.py:668, in FBPINNTrainer.train(self)
#     661     u_test_losses, start1, report_time = \
#     662     self._report(i, pstep, fstep, u_test_losses, start0, start1, report_time,
#     663                 u_exact, x_batch_test, test_inputs, all_params, all_opt_states, model_fns, problem, decomposition,
#     664                 active, merge_active, active_opt_states, active_params, x_batch,
#     665                 lossval)
#     667 # take a training step
# --> 668 lossval, active_opt_states, active_params = update(active_opt_states,
# ...

# %%
import numpy as np

from fbpinns.domains import RectangularDomainND
from fbpinns.problems import Gravity
from fbpinns.decompositions import MultilevelRectangularDecompositionND
from fbpinns.networks import FCN
from fbpinns.schedulers import AllActiveSchedulerND
from fbpinns.constants import Constants, get_subdomain_ws
from fbpinns.trainers import FBPINNTrainer

XMIN, XMAX, YMIN, YMAX = 0, 1, 0, 1

w = 3.4
subdomain_xss = [[np.array([0.5]),np.array([0.5])]] +\
    [[np.linspace(0,1,n_),np.linspace(0,1,n_)] for n_ in (5,)] +\
    [[np.linspace(0,1,n_),np.linspace(0,1,n_)] for n_ in (20,)]
subdomain_wss = [[np.array([1.]),np.array([1.])]] +\
    [get_subdomain_ws(subdomain_xss[1], w)] +\
    [get_subdomain_ws(subdomain_xss[2], w)]

c = Constants(
    domain=RectangularDomainND,
    domain_init_kwargs = dict(
        xmin=np.array([0.,0.]),
        xmax=np.array([3.,3.])
        ),
    problem=Gravity,
    problem_init_kwargs = dict(sd=0.1),
    decomposition=MultilevelRectangularDecompositionND,
    decomposition_init_kwargs=dict(
        subdomain_xss=subdomain_xss,
        subdomain_wss=subdomain_wss,
        unnorm=(0.,3.),
    ),
    network=FCN,
    network_init_kwargs = dict(
        layer_sizes = (2, 32, 1),
    ),
    optimiser_kwargs=dict(learning_rate=1e-3),
    scheduler = AllActiveSchedulerND,
    ns=((100,100),),
    n_test=(100,100),
    n_steps=100000,
    clear_output=True,
)

run = FBPINNTrainer(c)
all_params = run.train()
# Out:
# [INFO] 2024-12-11 00:40:26 - <fbpinns.constants.Constants object at 0x7f6cb32d20f0>
# run: test
# domain: <class 'fbpinns.domains.RectangularDomainND'>
# domain_init_kwargs: {'xmin': array([0., 0.]), 'xmax': array([3., 3.])}
# problem: <class 'fbpinns.problems.Gravity'>
# problem_init_kwargs: {'sd': 0.1}
# decomposition: <class 'fbpinns.decompositions.MultilevelRectangularDecompositionND'>
# decomposition_init_kwargs: {'subdomain_xss': [[array([0.5]), array([0.5])], [array([0.  , 0.25, 0.5 , 0.75, 1.  ]), array([0.  , 0.25, 0.5 , 0.75, 1.  ])], [array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#        0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#        0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#        0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ]), array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#        0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#        0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#        0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ])]], 'subdomain_wss': [[array([1.]), array([1.])], [array([0.85, 0.85, 0.85, 0.85, 0.85]), array([0.85, 0.85, 0.85, 0.85, 0.85])], [array([0.17894737, 0.17894737, 0.17894737, 0.17894737, 0.17894737,
#        0.17894737, 0.17894737, 0.17894737, 0.17894737, 0.17894737,
#        0.17894737, 0.17894737, 0.17894737, 0.17894737, 0.17894737,
#        0.17894737, 0.17894737, 0.17894737, 0.17894737, 0.17894737]), array([0.17894737, 0.17894737, 0.17894737, 0.17894737, 0.17894737,
#        0.17894737, 0.17894737, 0.17894737, 0.17894737, 0.17894737,
#        0.17894737, 0.17894737, 0.17894737, 0.17894737, 0.17894737,
#        0.17894737, 0.17894737, 0.17894737, 0.17894737, 0.17894737])]], 'unnorm': (0.0, 3.0)}
# network: <class 'fbpinns.networks.FCN'>
# network_init_kwargs: {'layer_sizes': (2, 32, 1)}
# n_steps: 100000
# scheduler: <class 'fbpinns.schedulers.AllActiveSchedulerND'>
# scheduler_kwargs: {}
# ns: ((100, 100),)
# n_test: (100, 100)
# sampler: grid
# optimiser: <function adam at 0x7f6d6e002160>
# optimiser_kwargs: {'learning_rate': 0.001}
# seed: 0
# summary_freq: 1000
# test_freq: 1000
# model_save_freq: 10000
# show_figures: True
# save_figures: False
# clear_output: True
# hostname: wephy-pc
#
# [INFO] 2024-12-11 00:40:27 - Total number of subdomains: 426
# [INFO] 2024-12-11 00:40:32 - Total number of trainable parameters:
# [INFO] 2024-12-11 00:40:32 - 	network: 54,954
# [INFO] 2024-12-11 00:40:33 - Total number of constraints: 1
# [INFO] 2024-12-11 00:40:34 - Computing exact solution..
# [INFO] 2024-12-11 00:40:34 - Computing done
# [INFO] 2024-12-11 00:40:34 - Getting test data inputs..
# [INFO] 2024-12-11 00:40:41 - [i: 0/100000] Updating active inputs..
# [INFO] 2024-12-11 00:40:40 - [i: 0/100000] Average number of points/dimension in active subdomains: 8.32
# [INFO] 2024-12-11 00:40:44 - [i: 0/100000] Updating active inputs done (2.22 s)
# [INFO] 2024-12-11 00:40:44 - [i: 0/100000] Compiling update step..
# [INFO] 2024-12-11 00:40:44 - x_batch
# [INFO] 2024-12-11 00:40:44 - (2304, 2), float32, JVPTracer
# [INFO] 2024-12-11 00:40:44 - x_take
# [INFO] 2024-12-11 00:40:44 - (29510, 2), float32, JVPTracer
# [INFO] 2024-12-11 00:40:44 - x_batch
# [INFO] 2024-12-11 00:40:44 - (2304, 2), float32, JVPTracer
# [INFO] 2024-12-11 00:40:44 - x_take
# [INFO] 2024-12-11 00:40:44 - (29510, 2), float32, JVPTracer
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 48
#      21 c = Constants(
#      22     domain=RectangularDomainND,
#      23     domain_init_kwargs = dict(
#    (...)
#      44     clear_output=True,
#      45 )
#      47 run = FBPINNTrainer(c)
# ---> 48 all_params = run.train()
#
# File ~/FBPINNs/fbpinns/trainers.py:651, in FBPINNTrainer.train(self)
#     649 logger.info(f"[i: {i}/{self.c.n_steps}] Compiling update step..")
#     650 static_params_dynamic, static_params_static = partition(static_params)
# --> 651 update = FBPINN_update.lower(optimiser_fn, active_opt_states,
#     652                              active_params, fixed_params, static_params_dynamic, static_params_static,
#     653                              takess, constraints, model_fns, jmapss, loss_fn).compile()
#     654 logger.info(f"[i: {i}/{self.c.n_steps}] Compiling done ({time.time()-startc:.2f} s)")
#     655 cost_ = update.cost_analysis()
#
#     [... skipping hidden 12 frame]
#
# File ~/FBPINNs/fbpinns/trainers.py:292, in FBPINN_update(optimiser_fn, active_opt_states, active_params, fixed_params, static_params_dynamic, static_params_static, takess, constraints, model_fns, jmapss, loss_fn)
#     290 static_params = combine(static_params_dynamic, static_params_static)
#     291 # update step
# --> 292 lossval, grads = value_and_grad(FBPINN_loss, argnums=0)(
#     293     active_params, fixed_params, static_params, takess, constraints, model_fns, jmapss, loss_fn)
#     294 updates, active_opt_states = optimiser_fn(grads, active_opt_states, active_params)
#     295 active_params = optax.apply_updates(active_params, updates)
#
#     [... skipping hidden 8 frame]
#
# File ~/FBPINNs/fbpinns/trainers.py:267, in FBPINN_loss(active_params, fixed_params, static_params, takess, constraints, model_fns, jmapss, loss_fn)
#     265     ujs = FBPINN_forward(all_params, x_batch, takes, model_fns, jmaps)
#     266     constraints_.append(constraint+ujs)
# --> 267 return loss_fn(all_params, constraints_)
#
# File ~/FBPINNs/fbpinns/problems.py:469, in Gravity.loss_fn(all_params, constraints)
#     466 f = jnp.zeros(x_batch.shape[0])
#     468 for source in sources:
# --> 469    f += norm(x_batch - source[0], axis=0)
#     471 phys = f.reshape((-1, 1)) + u_xx + u_yy
#     473 return jnp.mean(phys**2)
#
# File ~/pinns/venv/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:1050, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1049 def op(self, *args):
# -> 1050   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/pinns/venv/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:573, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     571 args = (other, self) if swap else (self, other)
#     572 if isinstance(other, _accepted_binop_types):
# --> 573   return binary_op(*args)
#     574 # Note: don't use isinstance here, because we don't want to raise for
#     575 # subclasses, e.g. NamedTuple objects that may override operators.
#     576 if type(other) in _rejected_binop_types:
#
# File ~/pinns/venv/lib/python3.12/site-packages/jax/_src/numpy/ufunc_api.py:177, in ufunc.__call__(self, out, where, *args)
#     175   raise NotImplementedError(f"where argument of {self}")
#     176 call = self.__static_props['call'] or self._call_vectorized
# --> 177 return call(*args)
#
#     [... skipping hidden 11 frame]
#
# File ~/pinns/venv/lib/python3.12/site-packages/jax/_src/numpy/ufuncs.py:1157, in _add(x, y)
#    1131 """Add two arrays element-wise.
#    1132
#    1133 JAX implementation of :obj:`numpy.add`. This is a universal function,
#    (...)
#    1154   Array([10, 11, 12, 13], dtype=int32)
#    1155 """
#    1156 x, y = promote_args("add", x, y)
# -> 1157 return lax.add(x, y) if x.dtype != bool else lax.bitwise_or(x, y)
#
#     [... skipping hidden 7 frame]
#
# File ~/pinns/venv/lib/python3.12/site-packages/jax/_src/lax/lax.py:2072, in broadcasting_shape_rule(name, *avals)
#    2070       result_shape.append(non_1s[0])
#    2071     else:
# -> 2072       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#    2073                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#    2075 return tuple(result_shape)
#
# TypeError: add got incompatible shapes for broadcasting: (2304,), (2,).
